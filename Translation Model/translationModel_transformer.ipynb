# %%
import csv
import string
import random
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

#setting the device to "cuda" if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
MAX_LENGTH=10

class Vocab_builder:
    def __init__(self):
        self.word_2_index={"<SOS>":0,"<EOS>":1,"<PAD>":2,"<UKN>":3}
        self.index_2_word={0:"<SOS>", 1:"<EOS>", 2:"<PAD>", 3:"<UKN>"}
        self.freq={}
        self.size=4

    def add_this_sentence(self,sentence):
        words=sentence.split(" ")
        for word in words:
            if word not in self.word_2_index:
                #If the word is not there, add it to a new index and store the indexes
                #Initialize the frequency of the word to 1 and increase the size of the vocabulary
                self.word_2_index[word]=self.size
                self.freq[word]=1
                self.index_2_word[self.size]=word
                self.size+=1
            else:
                # If the word is already present then just increase the frequency
                self.freq[word]+=1

# %%
#Initilizing the objects of hindi and english vocabularies:
hindi_vocab=Vocab_builder()
eng_vocab=Vocab_builder()

# %%
def length(sentence):
    return len(sentence.split(" "))

def is_mixed(sentence):
    letters="abcdefghijklmnopqrstuvwxyz"
    for ch in letters:
        if ch in sentence:
            return True
    return False

def preprocess(sentence):
    #First we will remove all punctuations from the sentence
    punctuations=list(string.punctuation)
    cleaned=""
    for letter in sentence:
        if letter not in punctuations:
            cleaned+=letter
    cleaned=cleaned.lower() ## Converting into lowercase
    return cleaned

# %%
def clean_the_data(path):
    pairs=[]
    with open(path,'rt') as f:
        data=csv.reader(f, delimiter=',')
        row_num=0
        for row in data:
            if row_num!=0:  #We will not process first row as it will contain header
                hindi=row[1]
                #print(row_num)
                #print(hindi)
                eng=row[2]
                #print(eng)

                if length(hindi)>=MAX_LENGTH or length(eng)>=MAX_LENGTH:  #skipping if length is more than MAX_LENGTH
                    continue
                if not hindi or not eng:  #skipping pair having any NULL value
                    continue
                if is_mixed(hindi):   #skipping sentence if it contains some english word
                    continue
                hindi=hindi.encode('utf-8',errors='ignore').decode('utf-8')
                eng=eng.encode('ascii',errors='ignore').decode('utf-8')
                hindi=preprocess(hindi)
                eng=preprocess(eng)
                #Adding <SOS>, <EOS> and padding tokens
                pair=[hindi.strip(), eng.strip()]

                hin_extra=MAX_LENGTH-len(hindi.strip().split(" "))
                eng_extra=MAX_LENGTH-len(eng.strip().split(" "))

                hindi_vocab.add_this_sentence(pair[0])
                eng_vocab.add_this_sentence(pair[1])
                pair[0]=pair[0].split(" ")
                pair[0].insert(0,"<SOS>")
                pair[0].append("<EOS>")
                pair[0]=pair[0]+["<PAD>"]*(hin_extra)

                pair[1]=pair[1].split(" ")
                pair[1].insert(0,"<SOS>")
                pair[1].append("<EOS>")
                pair[1]=pair[1]+["<PAD>"]*(eng_extra)

                pair[0]=" ".join(pair[0])
                pair[1]=" ".join(pair[1])
                pairs.append(pair)
            row_num+=1
    return pairs

# %%
file_path="/content/drive/MyDrive/"     
train_file_path=file_path+"train-set.csv"

# %%
pairs=clean_the_data(train_file_path)

# %%
pairs
# Out:
# [['<SOS> मैं उनके साथ कोई लेना देना नहीं है <EOS> <PAD> <PAD>',
#   '<SOS> i have nothing to do with them <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> हटाओ रिक <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> fuck them rick <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> क्योंकि यह एक खुशियों भरी फ़िल्म है <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> because its a happy film <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> क्या भाषा क्या वे वहाँ बात की <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> what language do they speak there <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> गन क्लिक करके <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> gun clicking <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> ये बिलकुल रोमांचकारी अनुभव है। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> its thrilling <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> ♪औरमैंउसे वहाँखड़े देखा थाएक <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> and i saw her standing there <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> बकवास आप क्या कर रहे हैं <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> what the fuck are you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> कोई प्यार के लिए एडी <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> no love for eddie <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> अच्छा विचार  अच्छा फोन छत पर <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> good idea good call on the roof <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> लानत है तुम पर <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> damn you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> और वह <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> and he <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> कानून मानव जाति के लिए लागू होता है <EOS> <PAD> <PAD>',
#   '<SOS> the law applies to human beings <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> सैदुल्ला साहिब गजब के व्यक्ति हैं । <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> saidullah sahib is an amazing man <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> 00 बजे काम पर आता हूं <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> when i come to work at 100 am <EOS> <PAD> <PAD>'],
#  ['<SOS> उसका चेहरा आकर्षक <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> her face ravishing <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आप पूरी तरह से पागल हो रहे हैं <EOS> <PAD> <PAD>',
#   '<SOS> are you completely mad <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> बाहर अपने टिकट है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> thats their ticket out <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> yb और हमने एक बच्चा बनाया <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> yb and we made a baby <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> नाव का हॉर्न बजता है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> boat horn blows <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मेरे पीछे 100 और गुप्तघातक आएँगे। <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> there are 100 more that will come after me <EOS> <PAD>'],
#  ['<SOS> आप अपने विचारों को सटीक बनाने के लिए है। <EOS> <PAD>',
#   '<SOS> you have to make your thoughts precise <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं वापस रहने के िलए कहा था <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> i told you to stay back <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> नहींएककम <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> no the lower one <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> कॉमरेड कप्तान <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> comrade captain <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> क्या हो रहा है यार <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> whats up man <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> कैरिना <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> carina <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> िकस जैसे <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> nothing like whom <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> सुदूर पूर्व के लिए एक बहादुर लोग <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> you remind me of the old tales <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> आपउसेमेरेबारेमेंचेतावनीदीहैयदि <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> if you warn anyone im coming <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> विंस्टन स्टोन। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> winston ston <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> कैसे आप वाला अंदर स्कॉट मिल रहे हैं <EOS> <PAD> <PAD>',
#   '<SOS> how are we gonna get scott inside <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> इसे अपनी आखिरी साँस तक महफ़ूज़ रखूँगा। <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> i will protect it with my last breath <EOS> <PAD> <PAD>'],
#  ['<SOS> हमें मदद चाहिये। हमें मदद चाहिये। <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> we need help we need help <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> पिता मित्रों की सभा के लिए धन्यवाद <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> father thank you for the gathering of friends <EOS> <PAD> <PAD>'],
#  ['<SOS> हेजिमयह है शॉन <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> hey jim its sean <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आपको याद है वे प्रारम्भिक गणित के मूल पहाड़े। <EOS> <PAD>',
#   '<SOS> you know the basics like multiplication tables <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> तुम मेरा पहला प्\u200dयार हो <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> you are my first love <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> नुकसान के रास्ते से बाहर <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> out of harms way <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> लेकिन तुम चारों ओर देखो। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> but look around you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> अरे <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> ah <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> यह बहुत अच्छा था <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> it was so good <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> जीएच ठीक है। सी जी बी ए और ई <EOS> <PAD>',
#   '<SOS> gh ok  c g b a and e <EOS> <PAD>'],
#  ['<SOS> पर जाएं <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> go on <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> अजीब बात है। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> its funny <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं अभी तक मरा नहीं हूँ <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> im not dead yet <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> वह जिंदा है। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> shes alive <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> समझ गया <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> roger <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> कैसा है ये <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> how is it <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हम पास होटल में एक अतिरिक्त रात comp <EOS> <PAD> <PAD>',
#   '<SOS> we got comp an extra night at the hotel <EOS> <PAD>'],
#  ['<SOS> मैं इस आदमी के आरोप में हूँ <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> im in charge of this guy <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> अठारह अठारह नकली है। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> even the weather is simulated <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> ड्यूक <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> duke <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> दो <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> two <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आपका नंबर क्या है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> whats your number <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> भाग्यशाली हो कि इतना मिल रहा है <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> youre lucky to get that much <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> तो वह स्वयंसेवक बन गई। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> so she signed up to be a volunteer <EOS> <PAD> <PAD>'],
#  ['<SOS> ये तो पिटाई नहीं बारात लग रही है <EOS> <PAD> <PAD>',
#   '<SOS> it looks like a procession not bashing up someone <EOS> <PAD>'],
#  ['<SOS> अब मरीज़ स्थानीय स्तर पर देखभाल पा सकते हैं। <EOS> <PAD>',
#   '<SOS> now patients can access care at a local level <EOS> <PAD>'],
#  ['<SOS> yellowjacket <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> the yellowjacket <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> चिल्लाती नीचे रहो <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> screams stay down <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हाँ और वह साथ एक मरीज को लाया है। <EOS> <PAD>',
#   '<SOS> yes and hes brought a patient along <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> साथ ही <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> thats capable of surviving a nuclear blast plus <EOS> <PAD> <PAD>'],
#  ['<SOS> अब मार्टिन <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> now martin tell me <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> निवास। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> the residence <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> यह छड़ी है इससे चोट नहीं लगती है <EOS> <PAD> <PAD>',
#   '<SOS> patent leather thats pretty <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैंएकयुद्धमें कियागयाहैमेरेदोस्त <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> i lived through one war comrade <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हम जीत गए। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> we have won <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> अपने आप को मूर्ख मत बनाओ <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> dont fool yourself <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> ठीक है। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> right <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हमारी मुटल्ली <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> our little fatty <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> लुई नीचे चला जाता है  आप इसे बाहर <EOS> <PAD>',
#   '<SOS> louis goes down you make it out <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> एक बड़ा अवसर <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> an enormous opportunity <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं कोई अनुचित बात नहीं कह रही हूँ <EOS> <PAD> <PAD>',
#   '<SOS> i am not being unreasonable <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> वे आ गए <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> i knew hed go <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैरी टॉड ने लिंकन को वो घड़ी <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> you know mary todd gave it to lincoln <EOS> <PAD> <PAD>'],
#  ['<SOS> मैंने कहा हम मिलकर काम करते हैं। <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> i said we work together <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> बहुत अफ़सोस है। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> im so so sorry <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> पैर कैसा है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> hows your leg <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> पहली पंक्ति के शहर के रूप में बर्लिन <EOS> <PAD> <PAD>',
#   '<SOS> berlin as a frontline city <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> टाटा <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> see you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> वे यहाँ नीचे ताल्लुक नहीं रखता। <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> they dont belong down here <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> इतनी जल्दी शॉपिंग कर लिया आपने <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> finished shopping so quickly <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आप रूस के लिए जाने के निर्देश दिए थे। <EOS> <PAD>',
#   '<SOS> you were instructed to go to russia <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> टी जेड  बिल्कुल सही। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> and now this  this is just like that <EOS> <PAD>'],
#  ['<SOS> और मैंने उसे चाट डाला <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> and i just ate it up <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> टीके धन्यवाद। तालियां <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> tk thank you applause <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> अच्छा <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> yeah sure <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> यह ऐसा ही है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> thats the way it is <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं बनाया है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> i did <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> यह कुछ भी नहीं था वाह <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> it wasnt anything wow <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मुझे बताओ मैं गलत हूँ <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> tell me im wrong <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> कराह रही लानत है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> groans damn it <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> क्षैतिज <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> horizontally <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> कोई 1 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> no 1 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हाँ मैं हूँ <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> yeah thats me <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हम क़रीब पहुंच रहे हैं। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> we are on final approach <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> बिजली तीखी आवाज कराहना <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> electricity crackling groaning <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> और वह अपने देखने के लिए चौकस थी <EOS> <PAD> <PAD>',
#   '<SOS> and she was always looking at watch <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> जिसे हम सीमा पर अंत में मिलने गए थे <EOS> <PAD>',
#   '<SOS> whom did we meet finally at the border <EOS> <PAD> <PAD>'],
#  ['<SOS> यह कोई परेशानी नहीं होगी। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> it would be no trouble <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> फ़िट्ज़पैट्रिक के शॉक से उबरने के लिए <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> to soften the blow of fitzpatricks return <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> सबसे अच्छा <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> the best <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> किसी ने फोन पर है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> someones on the phone <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> टिम का क्या होगा <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> what about tim <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> न कहने का कोई कारण नहीं है <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> i have no reason to tell you no <EOS> <PAD> <PAD>'],
#  ['<SOS> आज सुबह मैं उसकी कब्र के पास गयी थी <EOS> <PAD>',
#   '<SOS> i went to his grave this morning <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> बर्फ़ पड़ रही है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> its snowing <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> तालियाँ शुक्रिया <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> applause thank you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> लेकिन मैं केवल एक मूल्य के लिए यह दबाएँ <EOS> <PAD>',
#   '<SOS> but i only press it for a price <EOS> <PAD> <PAD>'],
#  ['<SOS> तुम बच गए <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> you survived it <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं रिबूट अनुक्रम कर सकते हैं <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> i can do the reboot sequence <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> तुम्हें अफसोस है हां  अफसोस है <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> welcome to the club <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> यह मेरे पिता को वह करना चाहता था चट्टानों <EOS> <PAD>',
#   '<SOS> this is what my father wanted to find <EOS> <PAD> <PAD>'],
#  ['<SOS> और साथ ही एक वाइकिंग भी। <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> and a viking <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> डिलीवरी ले लिया <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> delivery taken <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> यह बस गायब नहीं होने वाला <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> its not just going to disappear <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> विशाल बिविल्डर्बीस्ट के घर में। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> in the home of the great bewilderbeast <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> इसका कोई दूसरा उपाय नहीं है। <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> theres no other way <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आप पाउला मिले हैं <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> youve met paula <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> कौन है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> whos there <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं सब कुछ लिख लेती थी <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> i file everything <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> कत्जा वह कहता है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> katja he says <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> उसने मासूमियत से मुस्कुराया और मना कर दिया । <EOS> <PAD>',
#   '<SOS> she smiled innocently and said no <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> पांच <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> five <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> दीदी फ़ूल दे दीजिये <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> sister flower please <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> ग्रन्ट्स <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> grunts <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> ca चलिए उसे यहाँ दिखाते हैं <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> ca i think we have that lets show that <EOS> <PAD>'],
#  ['<SOS> नुक्सान किन में जमा हो सकता है <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> what can damage accumulate in <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> और मैं यहीं रुकता हूं धन्यवाद <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> thank you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> कौनसी नीतियां <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> what policies <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मेरा गाना हो गया। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> im done <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> वो ये क्यों कर रहा है <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> why is he doing this <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> अब आप अपने सवाल पूछते हो। <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> now ask your questions <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> चलो। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> go go <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं कभी आत्मसमर्पण नहीं करूंगा <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> i will never surrender <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> वरना यहाँ खड़े नहीं होते <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> were all immune or we wouldnt still be here <EOS> <PAD>'],
#  ['<SOS> क्या उनकी कोई छुपी हुई योजना है <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> do they have a hidden agenda <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं तुम्हें बचाने के लिए भागी। <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> i rushed to protect you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं इसे शांति का सूत्र कहता हूँ। <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> i call this my peace formula <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आदमी फोन पर <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> man on phone <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> यह रेंजर बेस आपातकालीन है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> this is ranger base emergency <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> तुम्हें मिल गया <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> you got it <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> अपने सभी नए धन आप वजन नीचे <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> all your new riches weighing you down <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं आप की सराहना कर सकता हूँ <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> im sure you can appreciate <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आप्का सर <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> your head <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> भगवान ने मुझे इस हार नहीं मानी। <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> god didnt give me this <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> इसने कहा तुम निकम्मे हो। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> he said youre a loser <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मुझे माफ करना मेरे प्यार कर रहा हूँ। <EOS> <PAD> <PAD>',
#   '<SOS> i am so sorry my love <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हर कोई प्यार के लिए चारों ओर चला जाएगा <EOS> <PAD>',
#   '<SOS> everyone will run around for love <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> कोई विस्फोट महोदय <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> no detonation sir <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> यह 150 मील प्रति घंटे पर चल सकता है <EOS> <PAD>',
#   '<SOS> it goes 150 miles an hour <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं बेबी कॉर्प में एक हस्ती हो जाऊँगा। <EOS> <PAD> <PAD>',
#   '<SOS> ill become a baby corp legend <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हां सब ठीक है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> yes all right <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हांमुझे पता नहीं यदि वो <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> oki dont know if those woman <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> बहुत वक्त लिया तैयार होने में <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> took you long enough <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> और वह गधा भूल गया <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> and she forgot a donkey <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> पुरुष <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> men <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मुझे अफसोस है कि आप पीड़ित हैं <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> now will you breed new hatreds with those guns <EOS> <PAD>'],
#  ['<SOS> ठीक है अब हम परिपथ के बाहर हैं <EOS> <PAD> <PAD>',
#   '<SOS> okay were out of orbit <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> स्कॉट क्या हुआ <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> scott whats wrong <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> माँ <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> mother <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> तो ऐसा कैसे संभव हुआ <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> well how did that happen <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आप आरक्षण के लिए जा रहे हैं <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> youre going to the reservation <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हाब्स <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> hobbs <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मुझे पता है यह हास्यास्पद है <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> i know its ridiculous <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आपकौनहैं <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> who what are you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> ए यह कैसा शोर है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> hey whats all the racket <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं कोई राक्षस नहीं। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> im not a monster <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> पर इस डेटा के पीछे भी एक कहानी है। <EOS> <PAD>',
#   '<SOS> but theres a story behind this data as well <EOS> <PAD>'],
#  ['<SOS> धीरे तो आप अंत में यह स्वीकार करते हैं <EOS> <PAD>',
#   '<SOS> softly so you finally admit it <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं तुम्हें सही मेरे परीक्षण के बाद लेने आऊँगा <EOS> <PAD>',
#   '<SOS> ill pick you up right after my test <EOS> <PAD> <PAD>'],
#  ['<SOS> आओ भी मुझे मूर्ख मत समझो। <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> come on mate dont take the piss <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> उन्होंने कहा कि उन्होंने नहीं किया था <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> he did didnt he <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> ठीक है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> its alright <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आदमी यह चारों ओर मोड़ <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> turn it around man <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> तुम तो पूरा शहर खरीद सकते हो <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> or will you even buy vizag <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> तो मैं अभी यह कर रहा हूँ <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> so this is what im doing now <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> वो हमें यहाँ मरने के लिए छोड़कर चले गए <EOS> <PAD>',
#   '<SOS> he left us here to die <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हम एग्जाम खत्म होने के बाद बात करेंगे <EOS> <PAD> <PAD>',
#   '<SOS> we can talk after i finish my exam <EOS> <PAD> <PAD>'],
#  ['<SOS> यह अर्थव्यवस्था के लिए भी अच्छा है। <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> its also good for the economy <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> दोस्तों एक बार <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> guys one time <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> सिग्ने मेरे प्रिय मत रोओ <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> signe my dear dont cry <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> कोई फर्क नहीं पड़ता <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> it makes no difference <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> अपना हाथ उठाईये अगर आप करते हैं <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> raise your hand if you do <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं उन सभी की कोशिश की <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> i tried them all <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हम क्या देख रहे हैं <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> what are we seeing <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं अपने उद्देश्य पूरा नहीं करते <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> i dont serve your purpose <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> जिप्सी आप अपने अधिकार पर आंदोलन है <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> gipsy you have movement on your right <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> उसने सोचा मैं इसे चाहते हैं। <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> he thought id want it <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> अलबतिना छुपी रुस्तम है। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> albatina is the hidden <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं आप फिर कभी नहीं हो सकता है <EOS> <PAD> <PAD>',
#   '<SOS> i might never see you again <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> कौन मांबाप इसके लिए तैयार होते हैं <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> what parent is equipped for that <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> और क्रिस्चियन और सोफुस <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> and christian and sofus <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> दुर्भाग्य से यह काफी फैली हुयी है <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> well unfortunately its pervasive <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> 28 साल पुराना है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> 28 years old <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> कुछ ही दिन के लिए रहेंगे <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> should only last a couple of days <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> चीखों के सिवाय सब खाया जा सकता है। <EOS> <PAD> <PAD>',
#   '<SOS> all edible except the squeal <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> जीवन के लिए जरुरी तत्व <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> the stuff of life <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> याद करने की कोशिश करो इंदु <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> try to recollect indu <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आप एक नई शुरुआत हो <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> you get a fresh start <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> उसे छोड़ दो दुर्गा <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> leave her alone durga <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> और हम अपने अनुभव साझा कर सकते हैं <EOS> <PAD> <PAD>',
#   '<SOS> and beyond that we can share our experience <EOS> <PAD> <PAD>'],
#  ['<SOS> आपको देख रहा है। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> looking at you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> कौन हो तुम बताओ <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> come out whoever you are <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हाँ चार्ली <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> yeah charlie <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> इस जगह को देखो <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> look at this place <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> नहीं वह नहीं करता है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> no he doesnt <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> और उसका प्रभाव हम सब पर पड़ेगा। <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> and that affects all of us <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आपने देखा होगा कि वहां क्या हुआ है <EOS> <PAD> <PAD>',
#   '<SOS> you have seen what has happened there <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> शुक्रिया यह बहुत अच्छा था फ्रॉलिन मैजियरली <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> thank you that was very good frulein manziarly <EOS> <PAD> <PAD>'],
#  ['<SOS> आप उस लड़की हैं आप नहीं कर रहे हैं <EOS> <PAD>',
#   '<SOS> youre that girl arent you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> एक महीने या दो <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> a month or two <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> धन्यवाद <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> music continues <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> वह तीन सप्ताह में सेवा की <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> he served three weeks <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आओ यार। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> come on you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> तुम्हें पता है छत में एक बड़ा छेद है। <EOS> <PAD>',
#   '<SOS> you know theres a big hole in the roof <EOS> <PAD>'],
#  ['<SOS> एक गुप्त पांडा <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> a secret panda <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> नएप्रकारउज्ज्वल और धूप ओर बहुत <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> theres a bright and sunny side too <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> यह दुर्भाग्य एक बिल्ली को मार रहा है <EOS> <PAD> <PAD>',
#   '<SOS> its bad luck killing a cat <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> फिक्शन साहसिक कथा <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> fiction adventure <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> यह ऐसा ही है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> its the same <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> तो तुम कहाँ बल्कि मर जाएगा <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> so where would you rather die <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> और हम ये प्रश्न ही नहीं उठाते । <EOS> <PAD> <PAD>',
#   '<SOS> and we do not ask this question <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> प्रियाआओ बेटी <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> priya come here <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> वे अमीर हैं <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> they are rich <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हम वास्तव में जाने के लिए है <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> do we really have to go <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मुझे क्या समझना चाहिए <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> what the hell am i supposed to think <EOS> <PAD> <PAD>'],
#  ['<SOS> हम बिस्तर में एक बहुत अच्छा समय है <EOS> <PAD> <PAD>',
#   '<SOS> we have a really good time in bed <EOS> <PAD> <PAD>'],
#  ['<SOS> बॉब अरे आज आप स्नान किया था <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> hey bob did you shower today <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> तुम क्या करने वाले हैं <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> what are you gonna do <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> वह आप भूल जाना चाहता हूँ बनाता है <EOS> <PAD> <PAD>',
#   '<SOS> she makes you want to forget <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> यह एक फ्लैश ड्राइव है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> its a flash drive <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> नहीं वह वरमोंट में स्कीइंग था <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> no he was skiing in vermont <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> अपने शिष्टाचार याद रखें <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> remember your manners <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> सब ठीक है सब ठीक है। <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> its okay its okay its okay <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मेरी परी <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> my angel <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> दूसरों को सचेत करो <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> warn the others <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> खुदा हूँ मै <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> im god <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हियाह <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> hiyah <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हम इसके चारों ओर जंगलियों की तरह नृत्य करेंगे <EOS> <PAD>',
#   '<SOS> well dance around it like wild injuns <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> इस बार हम एक वारंट मिला है <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> this time we got a warrant <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> काई ने वादी पर हमला बोल दिया। <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> kai attacked the valley <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आप हमें सुन सकते हैं <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> can you hear us <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> गृह सचिव के साथ स्कूल में पढ़ा था। <EOS> <PAD> <PAD>',
#   '<SOS> went to school with the home secretary <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> हैलो क्या गलत है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> hello whats wrong <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> तुम उसे नहीं ढूँढ़ पाओगे। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> you wont find her <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आपको शर्म और आत्मसंदेह से बाहर निकलना है। <EOS> <PAD> <PAD>',
#   '<SOS> youve got to push through shyness and selfdoubt <EOS> <PAD> <PAD>'],
#  ['<SOS> ढक्कन बंद करोगे <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> shut the lid will ya <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हम सही भुगतान किया हो रही है <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> were getting paid right <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> कौनसी बात तुम्हारी पहचान है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> what makes you you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> चलो कदम <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> lets move <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> केवल करीब तीन महीने <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> only about three months <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> करतल ध्वनि <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> applause <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> बाँध सही सलामत है। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> the dam is pretty much intact <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> बनाता है यह मुझे बहुत खुश <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> it makes me really happy <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> जॉन कृपया कुछ कहो। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> john please say something <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हम दो और लेते हैं प्रत्येक <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> we take two more each <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> के विचार के साथ मैं प्यार था <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> i was in love with the idea of love <EOS> <PAD>'],
#  ['<SOS> आप लोग अच्छे से घूमें। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> you guys have a good one <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> उन्होने इसे संभाल के रखा <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> they kept it close to them <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> अंडे चोरी <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> stealing eggs <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> नहीं मेरे मम्मीपापा ने मुझे बताया था कि <EOS> <PAD> <PAD>',
#   '<SOS> no my parents told me that <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> लेकिन मैं तुम्हें क्या बता देंगे <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> but ill tell you what <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हाँ पीतल इसे बढ़ा वाला है डर है <EOS> <PAD> <PAD>',
#   '<SOS> yeah the brass is afraid its gonna escalate <EOS> <PAD> <PAD>'],
#  ['<SOS> अरे यह उसकी मंगेतर <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> hey thats his fiance <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मेरा मुकाबला मेरे प्यारे क्षितिज से परे है <EOS> <PAD> <PAD>',
#   '<SOS> i have a rendezvous beyond my beloved horizon <EOS> <PAD> <PAD>'],
#  ['<SOS> मैने प्रतिक्रिया करनी शुरु कर दी थी <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> i started reacting <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> तुम लोगों के लिए चीयर्स <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> cheers to you guys <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> धत्। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> holy shit <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं तुम लोगों को सीढियों के नीचे मिलूंगी <EOS> <PAD> <PAD>',
#   '<SOS> ill meet you guys downstairs <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> वो झूठ बोल रहा था <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> he was running a fake show <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आप मुझ पर विश्वास करते हैं <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> do you trust me <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> कल शायद <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> tomorrow maybe <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं वहाँ से बाहर वापस मिलना चाहिए <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> i should get back out there <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> क्या बात है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> what is it <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> कि आप इस समय पर मुझे देखने आ जाएगा। <EOS> <PAD>',
#   '<SOS> that youll come see me at this hour <EOS> <PAD> <PAD>'],
#  ['<SOS> क्या आप चाहते हैं <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> what do you want <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> यह मेरी इच्छा है। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> thats my wish <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आप उसे देख रोक नहीं है <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> you dont stop looking at him <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> रूसी हर जगह से निकल कर आ रहे हैं <EOS> <PAD>',
#   '<SOS> the russians are breaking through everywhere <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> लेकिन हम गार्ड से कैसे बचेंगे <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> but how do we get past the guard <EOS> <PAD> <PAD>'],
#  ['<SOS> रेवेन <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> raven <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> तुम कैसे हो <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> how are you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> नहीं भी जर्जर है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> not too shabby <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> राम मैं गर्भवती हूँ <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> rama im pregnant <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> अध्ययन। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> study <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> ब्लैक हॉक्स आ रहे हैं। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> shit sir we have black hawks coming in <EOS> <PAD> <PAD>'],
#  ['<SOS> आप सही एक पुलिस वाले हैं <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> youre a cop right <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> क्या वे जानते हैं कि जहां हम रहते हैं <EOS> <PAD>',
#   '<SOS> do they know where we live <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आप को छिपाने के लिए नहीं है <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> you dont have to hide <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> तुम्हारे बच्चे <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> your children <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> st धन्यवाद मार्गारेट <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> st thank you margaret <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> ये यहाँ क्यों आये हैं <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> why are they here <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> भारी हथियारों से क्या मतलब है आपका <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> what do you mean heavy weapon <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आप <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> क्या आप कभी गिरफ़्तार हुई हैं <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> so have you been arrested <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हाँ सुन रहा है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> affirmative <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं आप को कम करके आंका <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> i underestimated you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> ठीक है। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> im on it <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> क्या तुम जानते हो कि क्या कह रहे हो <EOS> <PAD>',
#   '<SOS> do you know what youre saying <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> अंधीगली <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> roadblock <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> यह काम होने पर <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> when thats done <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हमें कुछ अधिक शक्तिशाली चाहिए। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> we need something more powerful <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हाँ <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> yeah <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> ये एक गधागाडी है जिसे विकसित किया है । <EOS> <PAD>',
#   '<SOS> and this is a donkey cart which they modified <EOS> <PAD>'],
#  ['<SOS> इसमें ग्रेजुएशन का सर्टिफ़िकेट होगा। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> a certificate of graduation should be in there <EOS> <PAD> <PAD>'],
#  ['<SOS> आशा है जहां अभी आप कर रहे हैं <EOS> <PAD> <PAD>',
#   '<SOS> hope where are you right now <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> उन्हें अलग तरीकों से इलाज करने की ज़रूरत थी। <EOS> <PAD>',
#   '<SOS> and they needed to be treated in different ways <EOS> <PAD>'],
#  ['<SOS> मैं क्या कर सकती हूं <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> what can i do <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हाँ हम करते हैं <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> yes we do <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> ये आप थे <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> it was you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> घुरघुराना <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> grunting <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> अरे चलो <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> hey come on <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> यह घर से दूर नहीं था <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> it was not away from home <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> 17 जनवरी 1989 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> january 17 1989 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> क्या हो रहा है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> whats happening <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> ये एक तरीका है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> this is one way <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हाथ और दस्ताने <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> hand and glove <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> साथ में ले जाएँ <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> move along <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> दफा हो जाओ पीले पेट <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> get lost yellowbelly <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> खुद को व्यापारिक जहाजों को बेचा। <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> sold i to the merchant ships <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> क्षेत्र के आसपास के सैन्य और पुलिस कर्मियों। <EOS> <PAD> <PAD>',
#   '<SOS> military and police personnel surrounding the area <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> सिर्फ मार्च नहीं कर सकते उनके बीच में। <EOS> <PAD> <PAD>',
#   '<SOS> cant just march into their midst <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> ठीक है शुक्रिया <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> okay ava <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> ये लोग यहाँ नहीं रह सकते <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> they cannot stay here <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> उसके साथ समुद्र में <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> into the sea with him <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> इस बार वह मंत्री के बेटे की पिटाई की। <EOS> <PAD>',
#   '<SOS> this time he beat up the ministers son <EOS> <PAD> <PAD>'],
#  ['<SOS> हम बस इसे पीछे रखना होगा <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> we just have to put it behind us <EOS> <PAD> <PAD>'],
#  ['<SOS> ट्रेवर  तुम ठीक हो <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> sean guys trevor <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> जी सर <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> yes sir <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आंटीउसने मुझे लात भी मारी थी <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> aunt he kicked too <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> पर्ल ब्लैकबेर्ड द्वारा उस बोतल में फंसे <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> the pearl trapped in that bottle by blackbeard <EOS> <PAD> <PAD>'],
#  ['<SOS> मैं होना उसकी मौत एक अर्थ है चाहता हूँ <EOS> <PAD>',
#   '<SOS> i want his death to be have a meaning <EOS> <PAD>'],
#  ['<SOS> मैं तुम्हारी घटिया खिड़कियाँ नहीं चाहती। <EOS> <PAD> <PAD> <PAD> <PAD>',
# ...
#  ['<SOS> बनाओ चट्टानों के लिए <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> we didnt get skewered <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> ठीक है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> all right <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> यह निर्भर करता है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> that depends <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं कर सकता हूँ मेरे प्यारे। <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> i can my dear <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> बस मुझे ब्रिस्टल में मिलता है <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> just get me into bristol <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हमारे पांचवें मार जीता <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> bagged our fifth kill <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हैलो <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> hello <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हेमहे <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> hem hey <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं तुम्हें पसंद करने लगाबेटे <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> i like you son <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> भावुक होने के लिए माफ़ करना। <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> oh hi mrs swan shouldnt you be somewhere else <EOS> <PAD>'],
#  ['<SOS> चलो मीटलग <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> come on meatlug <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> पहला फोकस है। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> first one is focus <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> क्या मैनें कहा था तुम्हें गोवा घुमाने के लिए <EOS> <PAD>',
#   '<SOS> did i ask you to take me around goa <EOS> <PAD>'],
#  ['<SOS> हाँ मुझे पता है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> yeah i know <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> चलो नहीं यार <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> no come on man <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> अरे तुम मज़ाक कर रहे हो <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> youve got to be shitting me <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हम आपको कुछ पैसे देने हैं <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> we owe you some money <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> भगवान लानत <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> god damn <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आप क्या कह रहे हैं <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> what are you saying <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> कुछ मोटे या पतले लगते हैं <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> that theres thicks and thins <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैंने इसे पहले भी कहीं देखा है। <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> ive seen this before somewhere <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> अरे हाँ इस बात का कारण उम <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> oh yeah cause of that um <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> यह एक पल सेना है। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> its an instant army <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> खास कर शनिवार को <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> especially on saturday <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> यकीन है कि उनका शैतानी नाम था <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> they sure had devilish names <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> और वहीं से मेरी दिशा बदल गयी। <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> and it was a turning point <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> वह आप परिचित लग रही है <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> does he look familiar to you <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> लेकिन वे एक राशन पर कर रहे हैं <EOS> <PAD> <PAD>',
#   '<SOS> but theyre on a ration <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं तो केवल मदद कर रही हूँ <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> im just helping out <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> अब भूजें कि हमें क्या दिखना शुरू हुआ <EOS> <PAD> <PAD>',
#   '<SOS> now guess what we started to see <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> प्रकाश बहुत है और यह अलग गिर जाएगा <EOS> <PAD> <PAD>',
#   '<SOS> too light and itll fall apart <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> नहीं बहुत देर हो चुकी <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> not too late <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैंअपनेही बिस्तरमें सोने के लिए जा रहा हूँ <EOS> <PAD> <PAD>',
#   '<SOS> im going to sleep in my own bed <EOS> <PAD> <PAD>'],
#  ['<SOS> वहाँ  टायर फटा आवाज़ <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> there tires screech <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> यह बहुत आसान है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> its almost too easy <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> अरे काफी जगह तुम यहाँ मिल गया है। <EOS> <PAD> <PAD>',
#   '<SOS> hey quite a place youve got here <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> औरतें खराब खाना नहीं बना सकती हैं <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> the woman cant bake worth shit <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> गधे। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> dickheads <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> लेकिन समय समाप्त हो रहा है। <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> but time is running out <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> कभी कभी। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> sometimes <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं नहीं कर सकता हूं बच्चे <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> i cant do that child <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> रेस कानून मुझे कहता है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> the race laws require me to ask you this <EOS> <PAD>'],
#  ['<SOS> तुम चर्च में हो <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> youre in a church <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> क्या 2052 के बारे में <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> what about 2052 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> वो यहां है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> hes here <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> लेकिन यह मेरे लिए भी आसान नहीं है <EOS> <PAD> <PAD>',
#   '<SOS> but this isnt easy for me either <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> मेरा मतलब है मैं समझ गया लेकिन वास्तविक प्यार <EOS> <PAD>',
#   '<SOS> i mean i get that but actual love <EOS> <PAD> <PAD>'],
#  ['<SOS> इसका आगमन हो रहा है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> it is coming <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> कृपया नहीं करते <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> please dont <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> घूरना बंद करें। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> stop staring <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> निकाला जाता है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> youre fired <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं अपने घर पर आमंत्रित किया है <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> i have invited you to my home <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> हम अभी भी उत्तर शीर्षक <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> we still heading north <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> राष्ट्रपति के लिए चल रहा है की तरह <EOS> <PAD> <PAD>',
#   '<SOS> like running for president <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आप ब्लू रे को जानते हो <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> you know blue ray <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> घूमना शुरू करो <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> initiating spin <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> स्ट्राइकर छलांग लगाने <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> striker take the leap <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मेरा खाना <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> heres my food <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> इस कटाना है। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> this is katana <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> सब कुछ ठीक है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> everythings fine <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> पॉल यंग ने केस कर डाला <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> is paul young suing us about the ad <EOS> <PAD> <PAD>'],
#  ['<SOS> मेरे दो लगा दो <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> put me down for two <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> माफ़ करना <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> im sorry <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> सुनो हम उन्हें आगाह करना है <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> listen we have to warn them <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> दुनिया के तो बुरे हाल हैं <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> the world is fucked up <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> गटागट पी जाओ। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> bottoms up <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> स्वस्थ दिखते हैं। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> healthy a little healthy <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आप हम सभी की जरूरत है क्या जानते हो <EOS> <PAD>',
#   '<SOS> do you know what we all need <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> या आप भी डर रहे हैं <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> or are you too scared <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> 60000 लोग बेघर हो गए। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> 600000 people were displaced <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> घातक खुराक <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> the lethal dose <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> और फिर इसे बंद कर दिया <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> and then it stopped <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हे भगवान तीन महीने पहले <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> oh god three months ago <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हम डैफ़कॉन 1 पर हैं। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> sir were at defcon 1 <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> खाने के बाद <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> after dinnertime <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> इसने इसके बारे में हमें तक नहीं बताया <EOS> <PAD> <PAD>',
#   '<SOS> she didnt even tell us about it <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> आज सुबह <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> this morning <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> किसी दिन मैं अपने मातापिता को बचाता। <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> some days i rescued my parents <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मेरी बात सुनो बहुत ध्यान से मेरे दोस्त <EOS> <PAD> <PAD>',
#   '<SOS> listen to me very carefully my friend <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> एक पिल्ला <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> a puppy <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> और वह वहाँ है। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> and there he is <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> नर्स <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> nurse <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हे <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> hey <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> भावनाएँ होना कोई कमज़ोरी नहीं है <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> having feelings isnt a sign of weakness <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> कौन जाने <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> who the hell knows <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> जूए मे कौन आलू हारा <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> who lost the potatoes to the game <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> वह सुंदर नहीं है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> isnt she pretty <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हर कोई चुप। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> everybody keep quiet <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> क्यूंकि वह अपने आप नही चल सकता। <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> because he cant make his way on his own <EOS> <PAD>'],
#  ['<SOS> कराहना <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> groaning <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैंएकदर्जीहूँ <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> tailor <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> और वास्तव में जो क्रिकेट ने किया है <EOS> <PAD> <PAD>',
#   '<SOS> and thats exactly what cricket has done <EOS> <PAD> <PAD> <PAD>'],
#  ['<SOS> उन्होंने कहा कि ऐसा नहीं करना चाहिए <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> he shouldnt have done that <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> एक बच्चे जादूगर का जीवन <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> the life of a child magician <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> उन्होंने कहा कि मुझे यहाँ लाया <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> he brought me here <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आप यहाँ शांति मिलेगी <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> you will find peace here <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> मैं हमेशा इसे मेरे साथ रखा है <EOS> <PAD> <PAD> <PAD>',
#   '<SOS> ive always kept it with me <EOS> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> आता क्यों नहीं मैं <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> why wouldnt i be coming <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> खैर यह यहीं है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> well its right here <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> इस कचरे से पिंड छुड़ाओ <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> get rid oi this crap <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> चलो करते हैं <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> lets do it <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> डॉलर <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> dollars <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> अपनीतकनीकनीचेखड़ेहै <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> have your tech stand down <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> हँसी और इस। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> laughter and this <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> अच्छी बात यह है कि हम क्या सोचते हैं <EOS> <PAD>',
#   '<SOS> well the point is thats what we think <EOS> <PAD> <PAD>'],
#  ['<SOS> तनाव नहीं नहीं यह हास्यास्पद है <EOS> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> straining no no thats ridiculous <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> यह मेरे सामने आया सबसे बड़ा अवसर है <EOS> <PAD> <PAD>',
#   '<SOS> this is the biggest one ive ever seen <EOS> <PAD> <PAD>'],
#  ['<SOS> रुकिए <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> wait <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> किसने पकड़ा <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> whos got you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ['<SOS> ओह मैं तुम से बेहतर विश्वास को जानता था <EOS> <PAD>',
#   '<SOS> oh i knew better than to trust you <EOS> <PAD> <PAD>'],
#  ['<SOS> वह सूरज ब्लॉक पहना था <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>',
#   '<SOS> she wore sun block <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>'],
#  ...]

# %%
len(pairs)
# Out:
# 55133

# %%
#Now we need to convert each of this pair into corresponding tensors
def pair_to_tensor(pair):
    hindi_sentence=pair[0]
    eng_sentence=pair[1]
    indexes_hindi=[hindi_vocab.word_2_index[word] for word in hindi_sentence.split(' ')]
    indexes_eng=[eng_vocab.word_2_index[word] for word in eng_sentence.split(' ')]
    hindi_tensor=torch.tensor(indexes_hindi, dtype=torch.long, device=device).view(-1,1)
    eng_tensor=torch.tensor(indexes_eng, dtype=torch.long, device=device).view(-1,1)
    return (hindi_tensor, eng_tensor)

# %%
hin_tensors=[]
eng_tensors=[]
for pair in pairs:      # we will convert each pair into tensor to process it
    hin,eng=pair_to_tensor(pair)
    hin_tensors.append(hin)
    eng_tensors.append(eng)

# %%
hin_tensors[0]
# Out:
# tensor([[ 0],
#         [ 4],
#         [ 5],
#         [ 6],
#         [ 7],
#         [ 8],
#         [ 9],
#         [10],
#         [11],
#         [ 1],
#         [ 2],
#         [ 2]], device='cuda:0')

# %%
hin_tensors[1]
# Out:
# tensor([[ 0],
#         [12],
#         [13],
#         [ 1],
#         [ 2],
#         [ 2],
#         [ 2],
#         [ 2],
#         [ 2],
#         [ 2],
#         [ 2],
#         [ 2]], device='cuda:0')

# %%
class Transformer_model(nn.Module):
    def __init__(self, embed_size, len_hin_vocab, len_eng_vocab, src_pad_index, num_heads, enc_layers, dec_layers, forward_exp, dropout, max_length,device):
        super(Transformer_model,self).__init__()
        self.hin_word_embed=nn.Embedding(len_hin_vocab, embed_size) #shape: (len_hin_vocab, embed_size)
        self.eng_word_embed=nn.Embedding(len_eng_vocab, embed_size) #shape: (len_eng_vocab, embed_size)
        self.hin_positional_embed=nn.Embedding(max_length, embed_size) #shape: (MAX_LENGTH, embed_size)
        self.eng_positional_embed=nn.Embedding(max_length, embed_size)  #shape: (MAX_LENGTH, embed_size)
        self.device=device
        self.transformer_layer=nn.Transformer(embed_size, num_heads,enc_layers, dec_layers, forward_expansion, dropout)
        self.out_fc=nn.Linear(embed_size, len_eng_vocab)    #linear layer to predicted the output word
        self.dropout=nn.Dropout(dropout)
        self.src_pad_index=src_pad_index

    def gen_mask_for_hindi(self, source):
        #need to transpose source as padding need to be of size (batch_size, seq_len) but source is of shape (seq_len, batch_size)
        source=source.transpose(0,1)
        mask=(source==self.src_pad_index) #(mask will contain 1 where there is pad token, and 0 otherwise)
        return mask.to(self.device)

    def forward(self, src, target):
        hin_seq_length, batch_size=src.shape
        eng_seq_length, batch_size=target.shape
        # creating positional embeddings to encode position of words in transformer (it will be just a range array upto max_length)
        hin_positional=torch.arange(0,hin_seq_length).unsqueeze(1).expand(hin_seq_length, batch_size).to(self.device)
        eng_positional=torch.arange(0,eng_seq_length).unsqueeze(1).expand(eng_seq_length, batch_size).to(self.device)
        # calculating embeddings as sum of positional and word embeddings
        hin_embedding=self.dropout(self.hin_word_embed(src)+self.hin_positional_embed(hin_positional))
        eng_embedding=self.dropout(self.eng_word_embed(target)+self.eng_positional_embed(eng_positional))
        # generating padding mask for hindi (source)
        hindi_padding_mask=self.gen_mask_for_hindi(src)
        # using in-built transformer function to generate mask for english (target)
        # It will be in form of a lower-triangular matrix
        eng_mask=self.transformer_layer.generate_square_subsequent_mask(eng_seq_length).to(self.device)
        output=self.transformer_layer(hin_embedding, eng_embedding, src_key_padding_mask=hindi_padding_mask, tgt_mask=eng_mask)
        output=self.out_fc(output)
        return output

# %% [markdown]
# **Training the Model**

# %%
# defining model parameters
embed_size=512
len_hin_vocab=hindi_vocab.size
len_eng_vocab=eng_vocab.size
padding_idx=eng_vocab.word_2_index["<PAD>"]
num_heads=8
enc_layers, dec_layers= 1,1
dropout=0.10
forward_expansion=4

# %%
model=Transformer_model(embed_size, len_hin_vocab, len_eng_vocab, padding_idx, num_heads, enc_layers, dec_layers, forward_expansion, dropout, MAX_LENGTH+2,device).to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/transformer.py:286: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(f"enable_nested_tensor is True, but self.use_nested_tensor is False because {why_not_sparsity_fast_path}")

# %%
model_available=False # A variable to indicate whether a model is present in the path or not

# %%
batch_size=64
optimizer=optim.Adam(model.parameters(),lr=0.001)
PATH="/content/hi_en_demo.pth"

epochs=2
epoch_loss=0.0

criterion=nn.CrossEntropyLoss(ignore_index=padding_idx) #ignore padding index while calculating loss

train_model=True #if need to train the model again, set it to True

if train_model == False:
    model = torch.load(PATH)
else:
    if model_available:
        model = torch.load(PATH)
    else:
        epochs_completed = 0
        while epochs_completed < epochs:
            epochs_completed += 1
            print(f"epoch {epochs_completed}/{epochs}")
            model.eval()
            model.train(True)
            cur_batch = 0
            idx = 0
            while idx < len(pairs):
                cur_batch += 1
                if cur_batch % 100 == 0:
                    print(f"    running batch {cur_batch} of {batches}")
                if idx + batch_size < len(pairs):
                    src_batch = hin_tensors[idx:idx+batch_size]
                    target_batch = eng_tensors[idx:idx+batch_size]
                else:
                    src_batch = hin_tensors[idx:]
                    target_batch = eng_tensors[idx:]

                src_batch = torch.cat(src_batch, dim=1).to(device)
                target_batch = torch.cat(target_batch, dim=1).to(device)
                output = model(src_batch, target_batch[:-1, :])
                output = output.reshape(-1, output.shape[2])

                target = target_batch[1:].reshape(-1)

                optimizer.zero_grad()
                loss = criterion(output, target)

                loss.backward()
                torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1)

                optimizer.step()
                epoch_loss += loss.item()

                idx += batch_size

            print(f"Epoch loss : {loss.item()}")

            torch.save(model, PATH)
            model_available = True
# Out:
# epoch 1/2
#     running batch 100 of 861
#     running batch 200 of 861
#     running batch 300 of 861
#     running batch 400 of 861
#     running batch 500 of 861
#     running batch 600 of 861
#     running batch 700 of 861
#     running batch 800 of 861
# Epoch loss : 4.024248123168945
# epoch 2/2
#     running batch 100 of 861
#     running batch 200 of 861
#     running batch 300 of 861
#     running batch 400 of 861
#     running batch 500 of 861
#     running batch 600 of 861
#     running batch 700 of 861
#     running batch 800 of 861
# Epoch loss : 3.456819772720337

# %%
def predict_translation(model, sentence, device, max_length=MAX_LENGTH):
    sentence = clean_sentence(sentence)
    tokens = sentence.split(" ")
    indexes = []
    for token in tokens:
        if token in hindi_vocab.word_2_index:
            indexes.append(hindi_vocab.word_2_index[token])
        else:
            indexes.append(hindi_vocab.word_2_index["<UKN>"])
    indexes = indexes[:MAX_LENGTH+2]  # model is trained on MAX_LENGTH sentences only so it expects sentences of this length only
    tensor_of_sentence = torch.LongTensor(indexes).unsqueeze(1).to(device)
    outputs = [0]  # adding <SOS> in the beginning of output
    while True:
        target_tensor = torch.LongTensor(outputs).unsqueeze(1).to(device)
        with torch.no_grad():
            output = model(tensor_of_sentence, target_tensor)
        pred = output.argmax(2)[-1, :].item()

        outputs.append(pred)

        if eng_vocab.index_2_word[pred] == "<EOS>":
            break

        if len(outputs) >= max_length:
            break

    final = []

    for i in outputs:
        if i == "<PAD>":
            break
        final.append(i)

    final = [eng_vocab.index_2_word[idx] for idx in final]
    translated = " ".join(final)
    return translated

# %%
from time import time

start=time()
print(predict_translation(model,'हमसफर',device))
end=time()

elapse=(end-start)*1000
print(f'Time elapses: {elapse}ms')
# Out:
# <SOS> all right <EOS>
# Time elapses: 98.72007369995117ms

# %%
test_sentences=[pair[0] for pair in pairs[125:150]]
actual_sentences=[pair[1] for pair in pairs[125:150]]
pred_sentences=[]

for idx,i in enumerate(test_sentences):
    translated=predict_translation(model,i,device)
    print("*"*20)
    print(f"Hindi: {i}")
    print(f"Actual: {actual_sentences[idx]}")
    print(f"Predicted: {translated}")
    print("*"*20)
# Out:
# ********************
# Hindi: <SOS> दीदी फ़ूल दे दीजिये <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> sister flower please <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> the whole doctor <EOS>
# ********************
# ********************
# Hindi: <SOS> ग्रन्ट्स <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> grunts <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> grunts <EOS>
# ********************
# ********************
# Hindi: <SOS> ca चलिए उसे यहाँ दिखाते हैं <EOS> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> ca i think we have that lets show that <EOS> <PAD>
# Predicted: <SOS> ca here <EOS>
# ********************
# ********************
# Hindi: <SOS> नुक्सान किन में जमा हो सकता है <EOS> <PAD> <PAD> <PAD>
# Actual: <SOS> what can damage accumulate in <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> the first is in the world <EOS>
# ********************
# ********************
# Hindi: <SOS> और मैं यहीं रुकता हूं धन्यवाद <EOS> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> thank you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> and i will i am <EOS>
# ********************
# ********************
# Hindi: <SOS> कौनसी नीतियां <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> what policies <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> the fhrer <EOS>
# ********************
# ********************
# Hindi: <SOS> मेरा गाना हो गया। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> im done <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> my is the same <EOS>
# ********************
# ********************
# Hindi: <SOS> वो ये क्यों कर रहा है <EOS> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> why is he doing this <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> thats why are they do it <EOS>
# ********************
# ********************
# Hindi: <SOS> अब आप अपने सवाल पूछते हो। <EOS> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> now ask your questions <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> now you do you do <EOS>
# ********************
# ********************
# Hindi: <SOS> चलो। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> go go <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> the phone <EOS>
# ********************
# ********************
# Hindi: <SOS> मैं कभी आत्मसमर्पण नहीं करूंगा <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> i will never surrender <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> i cant never heard <EOS>
# ********************
# ********************
# Hindi: <SOS> वरना यहाँ खड़े नहीं होते <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> were all immune or we wouldnt still be here <EOS> <PAD>
# Predicted: <SOS> no here not be here <EOS>
# ********************
# ********************
# Hindi: <SOS> क्या उनकी कोई छुपी हुई योजना है <EOS> <PAD> <PAD> <PAD>
# Actual: <SOS> do they have a hidden agenda <EOS> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> is someone a problem <EOS>
# ********************
# ********************
# Hindi: <SOS> मैं तुम्हें बचाने के लिए भागी। <EOS> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> i rushed to protect you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> i want to see you <EOS>
# ********************
# ********************
# Hindi: <SOS> मैं इसे शांति का सूत्र कहता हूँ। <EOS> <PAD> <PAD> <PAD>
# Actual: <SOS> i call this my peace formula <EOS> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> i am it on the middle last <EOS>
# ********************
# ********************
# Hindi: <SOS> आदमी फोन पर <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> man on phone <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> man on man <EOS>
# ********************
# ********************
# Hindi: <SOS> यह रेंजर बेस आपातकालीन है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> this is ranger base emergency <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> it is the game <EOS>
# ********************
# ********************
# Hindi: <SOS> तुम्हें मिल गया <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> you got it <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> you got it <EOS>
# ********************
# ********************
# Hindi: <SOS> अपने सभी नए धन आप वजन नीचे <EOS> <PAD> <PAD> <PAD>
# Actual: <SOS> all your new riches weighing you down <EOS> <PAD> <PAD> <PAD>
# Predicted: <SOS> your family are you get your eyes <EOS>
# ********************
# ********************
# Hindi: <SOS> मैं आप की सराहना कर सकता हूँ <EOS> <PAD> <PAD> <PAD>
# Actual: <SOS> im sure you can appreciate <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> i can do you do you <EOS>
# ********************
# ********************
# Hindi: <SOS> आप्का सर <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> your head <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> sorry sir sir <EOS>
# ********************
# ********************
# Hindi: <SOS> भगवान ने मुझे इस हार नहीं मानी। <EOS> <PAD> <PAD> <PAD>
# Actual: <SOS> god didnt give me this <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> i didnt want to me <EOS>
# ********************
# ********************
# Hindi: <SOS> इसने कहा तुम निकम्मे हो। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> he said youre a loser <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> it said you said you <EOS>
# ********************
# ********************
# Hindi: <SOS> मुझे माफ करना मेरे प्यार कर रहा हूँ। <EOS> <PAD> <PAD>
# Actual: <SOS> i am so sorry my love <EOS> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> im sorry for me <EOS>
# ********************
# ********************
# Hindi: <SOS> हर कोई प्यार के लिए चारों ओर चला जाएगा <EOS> <PAD>
# Actual: <SOS> everyone will run around for love <EOS> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> everyone has to go to love <EOS>
# ********************

# %%
test_sentences=[pair[0] for pair in pairs[125:150]]
actual_sentences=[pair[1] for pair in pairs[125:150]]
pred_sentences=[]

for idx,i in enumerate(test_sentences):
    translated=predict_translation(model,i,device)
    print("*"*20)
    print(f"Hindi: {i}")
    print(f"Actual: {actual_sentences[idx]}")
    print(f"Predicted: {translated}")
    print("*"*20)
# Out:
# ********************
# Hindi: <SOS> दीदी फ़ूल दे दीजिये <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> sister flower please <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> the data is a little bit <EOS>
# ********************
# ********************
# Hindi: <SOS> ग्रन्ट्स <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> grunts <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> grunts <EOS>
# ********************
# ********************
# Hindi: <SOS> ca चलिए उसे यहाँ दिखाते हैं <EOS> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> ca i think we have that lets show that <EOS> <PAD>
# Predicted: <SOS> ca here lets go here <EOS>
# ********************
# ********************
# Hindi: <SOS> नुक्सान किन में जमा हो सकता है <EOS> <PAD> <PAD> <PAD>
# Actual: <SOS> what can damage accumulate in <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> i have to be in the world <EOS>
# ********************
# ********************
# Hindi: <SOS> और मैं यहीं रुकता हूं धन्यवाद <EOS> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> thank you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> and i am i am <EOS>
# ********************
# ********************
# Hindi: <SOS> कौनसी नीतियां <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> what policies <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> in the first <EOS>
# ********************
# ********************
# Hindi: <SOS> मेरा गाना हो गया। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> im done <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> my cards are you <EOS>
# ********************
# ********************
# Hindi: <SOS> वो ये क्यों कर रहा है <EOS> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> why is he doing this <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> he said why <EOS>
# ********************
# ********************
# Hindi: <SOS> अब आप अपने सवाल पूछते हो। <EOS> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> now ask your questions <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> now you have your own <EOS>
# ********************
# ********************
# Hindi: <SOS> चलो। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> go go <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> and <EOS>
# ********************
# ********************
# Hindi: <SOS> मैं कभी आत्मसमर्पण नहीं करूंगा <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> i will never surrender <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> i never never never ever <EOS>
# ********************
# ********************
# Hindi: <SOS> वरना यहाँ खड़े नहीं होते <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> were all immune or we wouldnt still be here <EOS> <PAD>
# Predicted: <SOS> so not even stand here <EOS>
# ********************
# ********************
# Hindi: <SOS> क्या उनकी कोई छुपी हुई योजना है <EOS> <PAD> <PAD> <PAD>
# Actual: <SOS> do they have a hidden agenda <EOS> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> is there to the problem <EOS>
# ********************
# ********************
# Hindi: <SOS> मैं तुम्हें बचाने के लिए भागी। <EOS> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> i rushed to protect you <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> i will you to see you for <EOS>
# ********************
# ********************
# Hindi: <SOS> मैं इसे शांति का सूत्र कहता हूँ। <EOS> <PAD> <PAD> <PAD>
# Actual: <SOS> i call this my peace formula <EOS> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> i am it on the word <EOS>
# ********************
# ********************
# Hindi: <SOS> आदमी फोन पर <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> man on phone <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> man on man <EOS>
# ********************
# ********************
# Hindi: <SOS> यह रेंजर बेस आपातकालीन है <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> this is ranger base emergency <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> its a baby of fundamental <EOS>
# ********************
# ********************
# Hindi: <SOS> तुम्हें मिल गया <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> you got it <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> you get it <EOS>
# ********************
# ********************
# Hindi: <SOS> अपने सभी नए धन आप वजन नीचे <EOS> <PAD> <PAD> <PAD>
# Actual: <SOS> all your new riches weighing you down <EOS> <PAD> <PAD> <PAD>
# Predicted: <SOS> lets all your new family <EOS>
# ********************
# ********************
# Hindi: <SOS> मैं आप की सराहना कर सकता हूँ <EOS> <PAD> <PAD> <PAD>
# Actual: <SOS> im sure you can appreciate <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> i can you <EOS>
# ********************
# ********************
# Hindi: <SOS> आप्का सर <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> your head <EOS> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> sorry sir sir <EOS>
# ********************
# ********************
# Hindi: <SOS> भगवान ने मुझे इस हार नहीं मानी। <EOS> <PAD> <PAD> <PAD>
# Actual: <SOS> god didnt give me this <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> god i cant tell me <EOS>
# ********************
# ********************
# Hindi: <SOS> इसने कहा तुम निकम्मे हो। <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Actual: <SOS> he said youre a loser <EOS> <PAD> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> how did you say you <EOS>
# ********************
# ********************
# Hindi: <SOS> मुझे माफ करना मेरे प्यार कर रहा हूँ। <EOS> <PAD> <PAD>
# Actual: <SOS> i am so sorry my love <EOS> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> im sorry sorry i am my <EOS>
# ********************
# ********************
# Hindi: <SOS> हर कोई प्यार के लिए चारों ओर चला जाएगा <EOS> <PAD>
# Actual: <SOS> everyone will run around for love <EOS> <PAD> <PAD> <PAD> <PAD>
# Predicted: <SOS> everyone love you love <EOS>
# ********************

# %%
fp=open("/content/drive/MyDrive/Colab Notebooks/answer.txt","w")

# %%
# Path of the validation/test data
val_data_path="/content/drive/MyDrive/test-statements-phase1.csv"
with open(val_data_path, 'rt') as f:
    data=csv.reader(f, delimiter=',')
    row_num=0
    for row in data:
        if row_num==0:
            row_num+=1
            continue
        sentence=row[2].strip()
        translated=predict_translation(model,sentence,device)
        translated=translated.split(" ")[1:-1]  #removing SOS and EOS token before writing to the file
        translated=" ".join(translated)
        fp.write(translated+'\n')
        if row_num%500==0:
            print(f"sentence : {row_num}")
        row_num+=1
fp.close()
# Out:
# sentence : 500
# sentence : 1000
# sentence : 1500
# sentence : 2000
# sentence : 2500
# sentence : 3000
# sentence : 3500
# sentence : 4000
# sentence : 4500
# sentence : 5000
